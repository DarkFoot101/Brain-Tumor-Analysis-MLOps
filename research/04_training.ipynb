# %%
import os
os.chdir(r"\Users\Akhil\OneDrive\Desktop\animal-disease-classification-with-llm")

# %%
from dataclasses import dataclass
from pathlib import Path

@dataclass(frozen=True)
class TrainingConfig:
    root_dir: Path
    trained_model_path: Path
    updated_base_model_path: Path
    training_data: Path
    params_epochs: int
    params_batch_size: int
    params_image_size: list
    params_is_augmentation: bool

@dataclass(frozen=True)
class PrepareCallbacksConfig:
    root_dir: Path
    tensorboard_root_log_dir: Path
    checkpoint_model_filepath: Path

# %%
from classifier.constants import *
from classifier.utils.common import read_yaml, create_directories
import tensorflow as tf

# %%
class ConfigurationManager:
    def __init__(
        self,
        config_filepath: Path = CONFIG_FILE_PATH,
        params_filepath: Path = PARAMS_FILE_PATH,
    ):
        self.config = read_yaml(config_filepath)
        self.params = read_yaml(params_filepath)
        create_directories([Path(self.config.artifacts_root)])
    
    # Callback configuratoin that can be used for training time
    def get_prepare_callbacks_config(self) -> PrepareCallbacksConfig:
        config = self.config.prepare_callbacks
        model_ckpt_dir = os.path.dirname(config.checkpoint_model_filepath)
        create_directories(
            [
                Path(model_ckpt_dir),
                Path(config.tensorboard_root_log_dir)
            ]
        )
        prepare_callback_config = PrepareCallbacksConfig(
            root_dir=Path(config.root_dir),
            tensorboard_root_log_dir=Path(config.tensorboard_root_log_dir),
            checkpoint_model_filepath=Path(config.checkpoint_model_filepath)
        )
        return prepare_callback_config
    
    # Traiining configuration
    def get_training_config(self) -> TrainingConfig:
        training = self.config.training
        prepare_base_model = self.config.prepare_base_model
        params = self.params

        training_data = os.path.join(self.config.data_ingestion.unzip_dir, "brain_tumor_dataset")

        #  create folder, not file
        create_directories([Path(training.trained_model_path).parent])

        training_config = TrainingConfig(
            root_dir=Path(training.root_dir),
            trained_model_path=Path(training.trained_model_path),
            updated_base_model_path=Path(prepare_base_model.updated_base_model_path),
            training_data=Path(training_data),
            params_epochs=params.EPOCHS,
            params_batch_size=params.BATCH_SIZE,
            params_image_size=params.IMAGE_SIZE,
            params_is_augmentation=params.AUGMENTATION,
        )
        return training_config

# %%
# You can get this from tensorflow documentation itself!
import time
class PrepareCallbacks:
    def __init__(self, config: PrepareCallbacksConfig):
        self.config = config

    @property
    def _create_tb_callbacks(self):
        tb_running_log_dir = os.path.join(
            self.config.tensorboard_root_log_dir,
            f"tb_logs_at_{time.strftime('%Y%m%d-%H%M%S')}"
        )
        return tf.keras.callbacks.TensorBoard(log_dir=tb_running_log_dir)
    
    @property
    def _create_ckpt_callbacks(self):
        return tf.keras.callbacks.ModelCheckpoint(
            filepath=self.config.checkpoint_model_filepath,
            save_best_only=True
        )
    
    def get_callbacks(self):
        return [
            self._create_tb_callbacks,
            self._create_ckpt_callbacks
        ]

# %%
import os
import urllib.request as request
from zipfile import ZipFile
import tensorflow as tf
import time
from tensorflow import keras
import math

# %%
class Training:
    def __init__(self, config: TrainingConfig):
        self.config = config
    
    # def get_base_model(self):
    #     #  load without optimizer state
    #     self.model = tf.keras.models.load_model(
    #         self.config.updated_base_model_path,
    #         compile=False
    #     )

    #     #  compile fresh optimizer
    #     self.model.compile(
    #         optimizer=tf.keras.optimizers.SGD(),
    #         loss=tf.keras.losses.CategoricalCrossentropy(),
    #         metrics=["accuracy"]
    #     )
    def get_base_model(self):
        base_model = tf.keras.models.load_model(
            self.config.updated_base_model_path,
            compile=False
        )

        num_classes = self.train_generator.num_classes
        print(" Detected num_classes:", num_classes)

        #  If already correct, just compile
        if base_model.output_shape[-1] == num_classes:
            self.model = base_model
        else:
            x = base_model.layers[-2].output
            outputs = tf.keras.layers.Dense(num_classes, activation="softmax")(x)
            self.model = tf.keras.Model(inputs=base_model.input, outputs=outputs)

        self.model.compile(
            optimizer=tf.keras.optimizers.SGD(),
            loss=tf.keras.losses.CategoricalCrossentropy(),
            metrics=["accuracy"]
        )
    
    def train_valid_generator(self):

        datagenerator_kwargs = dict(
            rescale=1./255,
            validation_split=0.20
        )

        dataflow_kwargs = dict(
            target_size=self.config.params_image_size[:-1],
            batch_size=self.config.params_batch_size,
            interpolation="bilinear"
        )

        valid_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
            **datagenerator_kwargs
        )

        self.valid_generator = valid_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="validation",
            shuffle=False,
            **dataflow_kwargs
        )

        if self.config.params_is_augmentation:
            train_datagenerator = tf.keras.preprocessing.image.ImageDataGenerator(
                rotation_range=40,
                horizontal_flip=True,
                width_shift_range=0.2,
                height_shift_range=0.2,
                shear_range=0.2,
                zoom_range=0.2,
                **datagenerator_kwargs
            )
        else:
            train_datagenerator = valid_datagenerator

        self.train_generator = train_datagenerator.flow_from_directory(
            directory=self.config.training_data,
            subset="training",
            shuffle=True,
            **dataflow_kwargs
        )

        #  Optional debug prints
        print("Train samples:", self.train_generator.samples)
        print("Valid samples:", self.valid_generator.samples)
        print("Classes:", self.train_generator.class_indices)

    @staticmethod
    def save_model(path: Path, model: tf.keras.Model):
        path = Path(path)
        path.parent.mkdir(parents=True, exist_ok=True)  #  only make parent dir
        model.save(path)


    def train(self, callback_list: list):

        self.steps_per_epoch = math.ceil(self.train_generator.samples / self.train_generator.batch_size)
        self.validation_steps = math.ceil(self.valid_generator.samples / self.valid_generator.batch_size)

        self.model.fit(
            self.train_generator,
            epochs=self.config.params_epochs,
            steps_per_epoch=self.steps_per_epoch,
            validation_data=self.valid_generator,
            validation_steps=self.validation_steps,
            callbacks=callback_list
        )

        self.save_model(
            path=self.config.trained_model_path,
            model=self.model
        )

# %%
import tensorflow as tf
print(tf.executing_eagerly())
# Out:
# True

# %%
tf.config.run_functions_eagerly(True)

# %%
try:
    config = ConfigurationManager()

    prepare_callbacks_config = config.get_prepare_callbacks_config()
    prepare_callbacks = PrepareCallbacks(config=prepare_callbacks_config)
    callback_list = prepare_callbacks.get_callbacks()

    training_config = config.get_training_config()
    training = Training(config=training_config)

    # training.get_base_model()
    # training.train_valid_generator()
    training.train_valid_generator()
    training.get_base_model()
    training.train(callback_list=callback_list)

except Exception as e:
    raise e
# Out:
# [2026-01-20 11:39:56,504 - INFO - common - yaml file: config\config.yaml loaded successfully]
# [2026-01-20 11:39:56,508 - INFO - common - yaml file: params.yaml loaded successfully]
# created directory at: artifacts
# created directory at: artifacts\prepare_callbacks\checkpoint_dir
# created directory at: artifacts\prepare_callbacks\tensorboard_log_dir
# created directory at: artifacts\training
# Found 1404 images belonging to 4 classes.
# Found 5619 images belonging to 4 classes.
# Train samples: 5619
# Valid samples: 1404
# Classes: {'glioma': 0, 'healthy': 1, 'meningioma': 2, 'pituitary': 3}
#  Detected num_classes: 4
# Epoch 1/8
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 0s 9s/step - accuracy: 0.3479 - loss: 18.5436[2026-01-20 12:37:31,079 - WARNING - saving_api - You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`. ]
# 352/352 ━━━━━━━━━━━━━━━━━━━━ 3454s 10s/step - accuracy: 0.4052 - loss: 14.6311 - val_accuracy: 0.6859 - val_loss: 6.5621
# Epoch 2/8
# 124/352 ━━━━━━━━━━━━━━━━━━━━ 35:16 9s/step - accuracy: 0.5267 - loss: 8.3142
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2196\3800129819.py in ?()
#      13     training.train_valid_generator()
#      14     training.get_base_model()
#      15     training.train(callback_list=callback_list)
#      16
# ---> 17 except Exception as e:
#      18     raise e
#
# ~\AppData\Local\Temp\ipykernel_2196\2359192298.py in ?(self, callback_list)
#      98
#      99         self.steps_per_epoch = math.ceil(self.train_generator.samples / self.train_generator.batch_size)
#     100         self.validation_steps = math.ceil(self.valid_generator.samples / self.valid_generator.batch_size)
#     101
# --> 102         self.model.fit(
#     103             self.train_generator,
#     104             epochs=self.config.params_epochs,
#     105             steps_per_epoch=self.steps_per_epoch,
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     395             callbacks.on_epoch_begin(epoch)
#     396             with epoch_iterator.catch_stop_iteration():
#     397                 for begin_step, end_step, iterator in epoch_iterator:
#     398                     callbacks.on_train_batch_begin(begin_step)
# --> 399                     logs = self.train_function(iterator)
#     400                     callbacks.on_train_batch_end(end_step, logs)
#     401                     if self.stop_training:
#     402                         break
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(iterator)
#     237         def function(iterator):
#     238             if isinstance(
#     239                 iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240             ):
# --> 241                 opt_outputs = multi_step_on_iterator(iterator)
#     242                 if not opt_outputs.has_value():
#     243                     raise StopIteration
#     244                 return opt_outputs.get_value()
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in ?(self, *args, **kwds)
#     806   def __call__(self, *args, **kwds):
#     807     # Implements PolymorphicFunction.__call__.
#     808     if self._run_functions_eagerly:
#     809       with trace.Trace(self._name, tf_function_call="eager"):
# --> 810         return self._python_function(*args, **kwds)
#     811
#     812     # Only count the statistics the first time, before initialization took
#     813     # place.
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(iterator)
#     150         @tf.autograph.experimental.do_not_convert
#     151         def multi_step_on_iterator(iterator):
#     152             if self.steps_per_execution == 1:
#     153                 return tf.experimental.Optional.from_value(
# --> 154                     one_step_on_data(iterator.get_next())
#     155                 )
#     156
#     157             # the spec is set lazily during the tracing of `tf.while_loop`
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(data)
#     121                     None if isinstance(i, tf.experimental.Optional) else i
#     122                 ),
#     123                 data,
#     124             )
# --> 125             result = step_func(converted_data)
#     126             return result
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py in ?(self, *args, **kwds)
#     806   def __call__(self, *args, **kwds):
#     807     # Implements PolymorphicFunction.__call__.
#     808     if self._run_functions_eagerly:
#     809       with trace.Trace(self._name, tf_function_call="eager"):
# --> 810         return self._python_function(*args, **kwds)
#     811
#     812     # Only count the statistics the first time, before initialization took
#     813     # place.
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(data)
#     131         @tf.autograph.experimental.do_not_convert
#     132         def one_step_on_data(data):
#     133             """Runs a single training step on a batch of data."""
# --> 134             outputs = self.distribute_strategy.run(step_function, args=(data,))
#     135             outputs = reduce_per_replica(
#     136                 outputs,
#     137                 self.distribute_strategy,
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(***failed resolving arguments***)
#    1669       # tf.distribute supports Eager functions, so AutoGraph should not be
#    1670       # applied when the caller is also in Eager mode.
#    1671       fn = autograph.tf_convert(
#    1672           fn, autograph_ctx.control_status_ctx(), convert_by_default=False)
# -> 1673       return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(self, fn, args, kwargs)
#    3259     _require_cross_replica_or_default_context_extended(self)
#    3260     if kwargs is None:
#    3261       kwargs = {}
#    3262     with self._container_strategy().scope():
# -> 3263       return self._call_for_each_replica(fn, args, kwargs)
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\distribute\distribute_lib.py in ?(self, fn, args, kwargs)
#    4059   def _call_for_each_replica(self, fn, args, kwargs):
#    4060     with ReplicaContext(self._container_strategy(), replica_id_in_sync_group=0):
# -> 4061       return fn(*args, **kwargs)
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\autograph\impl\api.py in ?(*args, **kwargs)
#     641   def wrapper(*args, **kwargs):
#     642     with ag_ctx.ControlStatusCtx(status=ag_ctx.Status.DISABLED):
# --> 643       return func(*args, **kwargs)
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\backend\tensorflow\trainer.py in ?(self, data)
#      55
#      56         # Forward pass
#      57         with tf.GradientTape() as tape:
#      58             if self._call_has_training_arg:
# ---> 59                 y_pred = self(x, training=True)
#      60             else:
#      61                 y_pred = self(x)
#      62             loss = self._compute_loss(
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\models\functional.py in ?(self, inputs, training, mask, **kwargs)
#     179             masks = tree.flatten(mask)
#     180             for x, mask in zip(inputs, masks):
#     181                 if mask is not None:
#     182                     backend.set_keras_mask(x, mask)
# --> 183         outputs = self._run_through_graph(
#     184             inputs,
#     185             operation_fn=lambda op: operation_fn(
#     186                 op, training=training, **kwargs
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\ops\function.py in ?(self, inputs, operation_fn, call_fn)
#     202                 else:
#     203                     # Use NNX operation mapping
#     204                     operation = self._get_operation_for_node(node)
#     205                     op = operation_fn(operation)
# --> 206                     outputs = op(*args, **kwargs)
#     207
#     208                 # Update tensor_dict.
#     209                 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\models\functional.py in ?(*args, **kwargs)
#     640                 and value is not None
#     641             ):
#     642                 kwargs[name] = value
#     643
# --> 644         return operation(*args, **kwargs)
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\layers\layer.py in ?(self, *args, **kwargs)
#     975                     "layers will not see the mask."
#     976                 )
#     977         finally:
#     978             # Destroy call context if we created it
# --> 979             self._maybe_reset_call_context()
#     980
#     981         ################################################
#     982         # 8. Add a node in the graph for symbolic calls.
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
#     122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
# --> 124             del filtered_tb
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\ops\operation.py in ?(self, *args, **kwargs)
#      55             call_fn = traceback_utils.inject_argument_info_in_traceback(
#      56                 call_fn,
#      57                 object_name=(f"{self.__class__.__name__}.call()"),
#      58             )
# ---> 59             return call_fn(*args, **kwargs)
#      60
#      61         # Plain flow.
#      62         if any_symbolic_tensors(args, kwargs):
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\utils\traceback_utils.py in ?(*args, **kwargs)
#     213                 new_e = e
#     214             raise new_e.with_traceback(e.__traceback__) from None
#     215         finally:
#     216             del signature
# --> 217             del bound_signature
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\layers\convolutional\base_conv.py in ?(self, inputs)
#     256                 bias_shape = (1,) * (self.rank + 1) + (self.filters,)
#     257             else:
#     258                 bias_shape = (1, self.filters) + (1,) * self.rank
#     259             bias = ops.reshape(self.bias, bias_shape)
# --> 260             outputs = ops.add(outputs, bias)
#     261
#     262         if self.activation is not None:
#     263             return self.activation(outputs)
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\ops\numpy.py in ?(x1, x2)
#     233            [10 12]], shape=(2, 2), dtype=int32)
#     234     """
#     235     if any_symbolic_tensors((x1, x2)):
#     236         return Add().symbolic_call(x1, x2)
# --> 237     return backend.numpy.add(x1, x2)
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\backend\tensorflow\sparse.py in ?(x1, x2)
#     489                     x1 = tf.convert_to_tensor(x1)
#     490             elif isinstance(x2, tf.IndexedSlices):
#     491                 # x2 is an IndexedSlices, densify.
#     492                 x2 = tf.convert_to_tensor(x2)
# --> 493             return func(x1, x2)
#
# c:\Users\Akhil\Python\lib\site-packages\keras\src\backend\tensorflow\numpy.py in ?(x1, x2)
#     125         else:
#     126             data_format = "NCHW"
#     127         if len(x2.shape) > 1:
#     128             x2 = tf.squeeze(x2)
# --> 129         return tf.nn.bias_add(x1, x2, data_format=data_format)
#     130
#     131     return tf.add(x1, x2)
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\util\traceback_utils.py in ?(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#     153       raise e.with_traceback(filtered_tb) from None
#     154     finally:
# --> 155       del filtered_tb
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\util\dispatch.py in ?(*args, **kwargs)
#    1261
#    1262       # Fallback dispatch system (dispatch v1):
#    1263       try:
#    1264         return dispatch_target(*args, **kwargs)
# -> 1265       except (TypeError, ValueError):
#    1266         # Note: convert_to_eager_tensor currently raises a ValueError, not a
#    1267         # TypeError, when given unexpected types.  So we need to catch both.
#    1268         result = dispatch(op_dispatch_handler, args, kwargs)
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\ops\nn_ops.py in ?(value, bias, data_format, name)
#    3556     if not context.executing_eagerly():
#    3557       value = ops.convert_to_tensor(value, name="input")
#    3558       bias = ops.convert_to_tensor(bias, dtype=value.dtype, name="bias")
#    3559
# -> 3560     return gen_nn_ops.bias_add(value, bias, data_format=data_format, name=name)
#
# c:\Users\Akhil\Python\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py in ?(value, bias, data_format, name)
#     868         _ctx, "BiasAdd", name, value, bias, "data_format", data_format)
#     869       return _result
#     870     except _core._NotOkStatusException as e:
#     871       _ops.raise_from_not_ok_status(e, name)
# --> 872     except _core._FallbackException:
#     873       pass
#     874     try:
#     875       return bias_add_eager_fallback(
#
# KeyboardInterrupt:
